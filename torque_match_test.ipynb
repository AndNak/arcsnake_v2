# %%
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt


# Read in motor data
motor_data_folder = "tests/System Tests/PCBTesting_MaxTorque"
motor_id = 6
Kp = 40
Ki = 30
v = 20
TC = 2000
test_name = f"single_motor_ID{motor_id}_Kp{Kp}_Ki{Ki}_v{v}_TC{TC}"

# with open(f"{motor_data_folder}/{test_name}", 'r') as f:
# 	reader = csv.reader(f)
# 	for line in reader:
# 		print(line)

motor_data = pd.read_csv(f"{motor_data_folder}/{test_name}")
max_motor_torque = motor_data["torque"].max()

# Read in fts data
fts_file = "C:/Users/jlimk/Documents/4-10-24_motor_tests/screw6_max_torque_current_2000_Kp40_Ki30_speed20.csv"
fts_data = pd.read_csv(fts_file, skiprows=list(range(6)))
max_sensor_torque = fts_data[' Tz '].max()

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

fig.suptitle("Screw 6, Kp = 40, Speed = 20")
axes[0].plot(motor_data["angular speed"])
axes[0].plot(motor_data["torque"])
axes[0].axhline(max_motor_torque)
axes[0].legend(["ang vel", "torque"])
axes[0].set_xlabel("time")

axes[1].plot(fts_data[' Tz '])
axes[1].axhline(max_sensor_torque)
axes[1].legend(['Sensor Torque'])

plt.style.use('bmh')
plt.tight_layout()
plt.show()

measured_torque_constant = max_sensor_torque / max_motor_torque
print(f"Max Motor Torque = {max_motor_torque}")
print(f"Max Sensor Torque = {max_sensor_torque}")
print(f"Torque Constant = {measured_torque_constant}")
# Out:
# Max Motor Torque = 17.7890625
# Max Sensor Torque = 0.760402
# Torque Constant = 0.04274547913921827

# %%
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt


# Read in motor data
motor_data_folder = "tests/System Tests/PCBTesting_MaxTorque"
motor_id = 5
Kp = 40
Ki = 30
v = 30
TC = 2000
test_name = f"single_motor_ID{motor_id}_Kp{Kp}_Ki{Ki}_v{v}_TC{TC}"

# with open(f"{motor_data_folder}/{test_name}", 'r') as f:
# 	reader = csv.reader(f)
# 	for line in reader:
# 		print(line)

motor_data = pd.read_csv(f"{motor_data_folder}/{test_name}")
max_motor_torque = motor_data["torque"].max()

# Read in fts data
fts_file = f"C:/Users/jlimk/Documents/4-10-24_motor_tests/screw{motor_id}_max_torque_current_{TC}_Kp{Kp}_Ki{Ki}_speed{v}.csv"
fts_data = pd.read_csv(fts_file, skiprows=list(range(6)))
max_sensor_torque = fts_data[' Tz '].max()

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

fig.suptitle(f"Screw {motor_id}, Kp = {Kp}, Speed = {v}")
axes[0].plot(motor_data["angular speed"])
axes[0].plot(motor_data["torque"])
axes[0].axhline(max_motor_torque)
axes[0].legend(["ang vel", "torque"])
axes[0].set_xlabel("time")

axes[1].plot(fts_data[' Tz '])
axes[1].axhline(max_sensor_torque)
axes[1].legend(['Sensor Torque'])

plt.style.use('bmh')
plt.tight_layout()
plt.show()

measured_torque_constant = max_sensor_torque / max_motor_torque
print(f"Max Motor Torque = {max_motor_torque}")
print(f"Max Sensor Torque = {max_sensor_torque}")
print(f"Torque Constant = {measured_torque_constant}")
# Out:
# Max Motor Torque = 23.58984375
# Max Sensor Torque = 0.976707
# Torque Constant = 0.041403707898658715

# %%
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt


# Read in motor data
motor_data_folder = "tests/System Tests/PCBTesting_MaxTorque"
motor_id = 5
Kp = 120
Ki = 30
v = 30
TC = 2000
test_name = f"single_motor_ID{motor_id}_Kp{Kp}_Ki{Ki}_v{v}_TC{TC}"

# with open(f"{motor_data_folder}/{test_name}", 'r') as f:
# 	reader = csv.reader(f)
# 	for line in reader:
# 		print(line)

motor_data = pd.read_csv(f"{motor_data_folder}/{test_name}")
max_motor_torque = motor_data["torque"].max()

# Read in fts data
fts_file = f"C:/Users/jlimk/Documents/4-10-24_motor_tests/screw{motor_id}_max_torque_current_{TC}_Kp{Kp}_Ki{Ki}_speed{v}.csv"
fts_data = pd.read_csv(fts_file, skiprows=list(range(6)))
max_sensor_torque = fts_data[' Tz '].max()

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

fig.suptitle(f"Screw {motor_id}, Kp = {Kp}, Speed = {v}")
axes[0].plot(motor_data["angular speed"])
axes[0].plot(motor_data["torque"])
axes[0].axhline(max_motor_torque)
axes[0].legend(["ang vel", "torque"])
axes[0].set_xlabel("time")

axes[1].plot(fts_data[' Tz '])
axes[1].axhline(max_sensor_torque)
axes[1].legend(['Sensor Torque'])

plt.style.use('bmh')
plt.tight_layout()
plt.show()

measured_torque_constant = max_sensor_torque / max_motor_torque
print(f"Max Motor Torque = {max_motor_torque}")
print(f"Max Sensor Torque = {max_sensor_torque}")
print(f"Torque Constant = {measured_torque_constant}")
# Out:
# Max Motor Torque = 32.46826171875
# Max Sensor Torque = 1.351715
# Torque Constant = 0.04163188690879013

# %%
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt


# Read in motor data
motor_data_folder = "tests/System Tests/PCBTesting_MaxTorque"
motor_id = 9
Kp = 40
Ki = 30
v = 20
TC = 2000
test_name = f"single_motor_ID{motor_id}_Kp{Kp}_Ki{Ki}_v{v}_TC{TC}"

# with open(f"{motor_data_folder}/{test_name}", 'r') as f:
# 	reader = csv.reader(f)
# 	for line in reader:
# 		print(line)

motor_data = pd.read_csv(f"{motor_data_folder}/{test_name}")
max_motor_torque = motor_data["torque"].max()

# Read in fts data
fts_file = f"C:/Users/jlimk/Documents/4-10-24_motor_tests/screw{motor_id}_max_torque_current_{TC}_Kp{Kp}_Ki{Ki}_speed{v}.csv"
fts_data = pd.read_csv(fts_file, skiprows=list(range(6)))
max_sensor_torque = fts_data[' Tz '].max()

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

fig.suptitle(f"Screw {motor_id}, Kp = {Kp}, Speed = {v}")
axes[0].plot(motor_data["angular speed"])
axes[0].plot(motor_data["torque"])
axes[0].axhline(max_motor_torque)
axes[0].legend(["ang vel", "torque"])
axes[0].set_xlabel("time")

axes[1].plot(fts_data[' Tz '][:4000])
axes[1].axhline(max_sensor_torque)
axes[1].legend(['Sensor Torque'])

plt.style.use('bmh')
plt.tight_layout()
plt.show()

measured_torque_constant = max_sensor_torque / max_motor_torque
print(f"Max Motor Torque = {max_motor_torque}")
print(f"Max Sensor Torque = {max_sensor_torque}")
print(f"Torque Constant = {measured_torque_constant}")
# Out:
# Max Motor Torque = 20.25439453125
# Max Sensor Torque = 2.319533
# Torque Constant = 0.11451998707842144

# %%
import numpy as np
import csv
import pandas as pd
import matplotlib.pyplot as plt


# Read in motor data
motor_data_folder = "tests/System Tests/PCBTesting_MaxTorque"
motor_id = 9
Kp = 40
Ki = 30
v = 30
TC = 2000
test_name = f"single_motor_ID{motor_id}_Kp{Kp}_Ki{Ki}_v{v}_TC{TC}_test"

# with open(f"{motor_data_folder}/{test_name}", 'r') as f:
# 	reader = csv.reader(f)
# 	for line in reader:
# 		print(line)

motor_data = pd.read_csv(f"{motor_data_folder}/{test_name}")
max_motor_torque = motor_data["torque"].max()

# Read in fts data
fts_file = f"C:/Users/jlimk/Documents/4-10-24_motor_tests/screw{motor_id}_max_torque_current_{TC}_Kp{Kp}_Ki{Ki}_speed{v}.csv"
fts_data = pd.read_csv(fts_file, skiprows=list(range(6)))
max_sensor_torque = fts_data[' Tz '].max()

fig, axes = plt.subplots(1, 2, figsize=(12, 6))

fig.suptitle(f"Screw {motor_id}, Kp = {Kp}, Speed = {v}")
axes[0].plot(motor_data["angular speed"])
axes[0].plot(motor_data["torque"])
axes[0].axhline(max_motor_torque)
axes[0].legend(["ang vel", "torque"])
axes[0].set_xlabel("time")

axes[1].plot(fts_data[' Tz '])
axes[1].axhline(max_sensor_torque)
axes[1].legend(['Sensor Torque'])

plt.style.use('classic')
plt.tight_layout()
plt.show()

measured_torque_constant = max_sensor_torque / max_motor_torque
print(f"Max Motor Torque = {max_motor_torque}")
print(f"Max Sensor Torque = {max_sensor_torque}")
print(f"Torque Constant = {measured_torque_constant}")
# Out:
# Max Motor Torque = 26.8125
# Max Sensor Torque = 2.205884
# Torque Constant = 0.08227073193473194

# %%
6.5*0.041
# Out:
# 0.2665
